# %% [markdown]
# # Getting familiar with Qrisp

# %% [markdown]
# ## Creating a QuantumVariable
#
# The central building block of Qrisp algorithms is the QuantumVariable. A QuantumVariable hides the qubit management from the user, enables human readable in- and outputs, strong typing via class inheritance, infix arithmetic syntax and much more. Creating a QuantumVariable is simple:

# %%
! pip install qrisp==0.6
# Out:
# Collecting qrisp==0.6
#   Downloading qrisp-0.6-py3-none-any.whl.metadata (4.5 kB)
# Collecting qiskit>=0.44.0 (from qrisp==0.6)
#   Downloading qiskit-2.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from qrisp==0.6) (3.10.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from qrisp==0.6) (1.16.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from qrisp==0.6) (0.60.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from qrisp==0.6) (3.6.1)
# Collecting tdqm (from qrisp==0.6)
#   Downloading tdqm-0.0.1.tar.gz (1.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from qrisp==0.6) (0.3.8)
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (from qrisp==0.6) (3.1.3)
# Collecting waitress (from qrisp==0.6)
#   Downloading waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from qrisp==0.6) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from qrisp==0.6) (2.32.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from qrisp==0.6) (5.9.5)
# Collecting jax==0.4.28 (from qrisp==0.6)
#   Downloading jax-0.4.28-py3-none-any.whl.metadata (23 kB)
# Collecting jaxlib==0.4.28 (from qrisp==0.6)
#   Downloading jaxlib-0.4.28-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from jax==0.4.28->qrisp==0.6) (0.5.4)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from jax==0.4.28->qrisp==0.6) (2.0.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.12/dist-packages (from jax==0.4.28->qrisp==0.6) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp==0.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp==0.6) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp==0.6) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp==0.6) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp==0.6) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp==0.6) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp==0.6) (2.9.0.post0)
# Collecting rustworkx>=0.15.0 (from qiskit>=0.44.0->qrisp==0.6)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit>=0.44.0->qrisp==0.6)
#   Downloading stevedore-5.7.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.44.0->qrisp==0.6) (4.15.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask->qrisp==0.6) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask->qrisp==0.6) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask->qrisp==0.6) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask->qrisp==0.6) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask->qrisp==0.6) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask->qrisp==0.6) (3.1.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->qrisp==0.6) (0.43.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->qrisp==0.6) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->qrisp==0.6) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->qrisp==0.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->qrisp==0.6) (2026.2.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from tdqm->qrisp==0.6) (4.67.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.1->qrisp==0.6) (1.17.0)
# Downloading qrisp-0.6-py3-none-any.whl (692 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 692.7/692.7 kB 12.5 MB/s eta 0:00:00
# Downloading jax-0.4.28-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 44.7 MB/s eta 0:00:00
# Downloading jaxlib-0.4.28-cp312-cp312-manylinux2014_x86_64.whl (77.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 MB 12.5 MB/s eta 0:00:00
# Downloading qiskit-2.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 105.2 MB/s eta 0:00:00
# Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 4.2 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 85.0 MB/s eta 0:00:00
# Downloading stevedore-5.7.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.2 MB/s eta 0:00:00
# Building wheels for collected packages: tdqm
#   Building wheel for tdqm (setup.py) ... done
#   Created wheel for tdqm: filename=tdqm-0.0.1-py3-none-any.whl size=1322 sha256=0dd23d5747e2bca8f41f9fab2f4f8938782a83e1a7ff5a868d8a329b14cfa36f
#   Stored in directory: /root/.cache/pip/wheels/af/02/71/aae0f7ee738abf19498353918ddae0f90a0d6ceb337b0bbc91
# Successfully built tdqm
# Installing collected packages: waitress, tdqm, stevedore, rustworkx, qiskit, jaxlib, jax, qrisp
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.7.2
#     Uninstalling jaxlib-0.7.2:
#       Successfully uninstalled jaxlib-0.7.2
#   Attempting uninstall: jax
#     Found existing installation: jax 0.7.2
#     Uninstalling jax-0.7.2:
#       Successfully uninstalled jax-0.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flax 0.11.2 requires jax>=0.6.0, but you have jax 0.4.28 which is incompatible.
# optax 0.2.7 requires jax>=0.5.3, but you have jax 0.4.28 which is incompatible.
# optax 0.2.7 requires jaxlib>=0.5.3, but you have jaxlib 0.4.28 which is incompatible.
# orbax-checkpoint 0.11.33 requires jax>=0.6.0, but you have jax 0.4.28 which is incompatible.
# Successfully installed jax-0.4.28 jaxlib-0.4.28 qiskit-2.3.1 qrisp-0.6 rustworkx-0.17.1 stevedore-5.7.0 tdqm-0.0.1 waitress-3.0.2

# %%
from qrisp import QuantumVariable

qv = QuantumVariable(5)

# %% [markdown]
# Here, 5 refers to the number of qubits the QuantumVariable represents.
# QuantumVariables allow for convenient quantum function construction and evaluation, since a QuantumVariable carries all the information that is relevant for performing quantum operations on it.
#
# QuantumVariables can be low-level manipulated by calling gate application functions on them:

# %%
from qrisp import h, z, cx

h(qv[0])
z(qv)
cx(qv[0], qv[3])
# Out:
# (Qubit(qv.0), Qubit(qv.3))

# %% [markdown]
# Note that the Z gate is applied to all qubits of `qv` since there is no qubit specified.
#
# In order to take a look at the generated circuit, we call `print` on the QuantumSession in which `qv` is registered:

# %%
print(qv.qs)
# Out:
# QuantumCircuit:
# ---------------
#       ┌───┐┌───┐
# qv.0: ┤ H ├┤ Z ├──■──
#       ├───┤└───┘  │
# qv.1: ┤ Z ├───────┼──
#       ├───┤       │
# qv.2: ┤ Z ├───────┼──
#       ├───┤     ┌─┴─┐
# qv.3: ┤ Z ├─────┤ X ├
#       ├───┤     └───┘
# qv.4: ┤ Z ├──────────
#       └───┘
# Live QuantumVariables:
# ----------------------
# QuantumVariable qv

# %% [markdown]
# Once the QuantumVariable is not needed anymore, we can call the `delete` method, to tell the qubit manager, to free up the corresponding qubits. Calling `delete` enables the qubits of `qv` to be reused at a later point for other purposes.

# %%
try:
    qv.delete(verify=True)
except Exception as e:
    print(e)
# Out:
# Tried to delete qubits not in |0> state

# %% [markdown]
# If given the keyword argument `verify`, Qrisp will check if the deleted qubits are properly disentangled by querying a simulator. Note that `verify` is set to `False` by default as the simulation can be resource costly for algorithms, which are creating and destroying a lot of QuantumVariables.
#
# In this case, the qubits are not ready to use for other purposes as they still are in a non-trivial state. If `qv` is entangled to other qubits, a simple reset would result in a non-unitary collapse of superposition. We would need to perform a procedure which is commonly called uncomputation.
#
# QuantumVariables can be thought of as the abstract parent class of more special types. One example is the QuantumChar:

# %%
from qrisp import QuantumChar

qch = QuantumChar()

# %% [markdown]
# In order to initialize `qch`, we use the slicing operator (which invokes the encode method):

# %%
qch[:] = "e"

# %% [markdown]
# We can check the content using a simple `print` call:

# %%
print(qch)
# Out:
# {'e': 1.0}

# %% [markdown]
# This command queries a simulator which evaluates the compiled quantum circuit. The measurement results are returned as bitstrings, which are then converted to the corresponding outcome value. Here, the 1.0 corresponds to the probability of the outcome `'e'`.
#
# In order to bring some quantumness into the script, we can entangle it to our previously created QuantumVariable:

# %%
cx(qv[0], qch[0])
print(qch)
# Out:
# {'e': 0.5, 'f': 0.5}

# %% [markdown]
# This brings the 0-th qubit of `qch` into a superposition and therefore `'f'` now appears with 50% probability.
#
# If we want to apply further processing to the measurement results, we can retrieve them as a dictionary using the `get_measurement` method:

# %%
results = qch.get_measurement()

# %% [markdown]
# And that's it - you're set with the basics and ready to build some algorithms!
#
# ## Solving a quadratic equation using Grover's algorithm
#
# As a first example, we showcase how to solve the quadratic equation
#
# $$x^2 = 0.25$$
#
# using Grover's algorithm. The idea here is to prepare an oracle, that multiplies a QuantumFloat with itself and tags the desired value $c_{tag} = 0.25$. This oracle is then embedded into several Grover iterations to amplify the amplitude of the solution.

# %% [markdown]
# ### Oracle Construction
#
# We start with elaborating the oracle construction:

# %%
from qrisp import auto_uncompute, z, h, QuantumFloat


@auto_uncompute
def sqrt_oracle(qf):
    temp_qbool = qf * qf == 0.25
    z(temp_qbool)

# %% [markdown]
# This oracle receives a [QuantumFloat](../../reference/Quantum%20Types/QuantumFloat.rst) `qf` and evaluates the square. Subsequently it determines whether the result is equal to 0.25, which returns the [QuantumBool](../../reference/Quantum%20Types/QuantumBool.rst) `temp_qbool`. Finally, we perform a Z gate on `temp_qbool`. Note the `auto_uncompute` decorator, which automatically uncomputes all temporary values of this function (i.e. the result of the multiplication and `temp_qbool`). You can find more information about Qrisps automatic uncomputation in [Uncomputation](../../reference/Core/Uncomputation.rst).
#
# To inspect the circuit, we create a QuantumFloat, evaluate the oracle and call `print` on the `.qs` attribute:

# %%
qf = QuantumFloat(3, -1, signed=True)
sqrt_oracle(qf)
print(qf.qs)
# Out:
# QuantumCircuit:
# ---------------
#               ┌───────────┐                            ┌──────────────┐
#         qf.0: ┤0          ├────────────────────────────┤0             ├
#               │           │                            │              │
#         qf.1: ┤1          ├────────────────────────────┤1             ├
#               │           │                            │              │
#         qf.2: ┤2          ├────────────────────────────┤2             ├
#               │           │                            │              │
#         qf.3: ┤3          ├────────────────────────────┤3             ├
#               │           │┌────────┐     ┌───────────┐│              │
#    mul_res.0: ┤4          ├┤0       ├─────┤0          ├┤4             ├
#               │           ││        │     │           ││              │
#    mul_res.1: ┤5          ├┤1       ├─────┤1          ├┤5             ├
#               │           ││        │     │           ││              │
#    mul_res.2: ┤6          ├┤2       ├─────┤2          ├┤6             ├
#               │           ││        │     │           ││              │
#    mul_res.3: ┤7          ├┤3       ├─────┤3          ├┤7             ├
#               │           ││        │     │           ││              │
#    mul_res.4: ┤8  __mul__ ├┤4       ├─────┤4          ├┤8  __mul___dg ├
#               │           ││        │     │           ││              │
#    mul_res.5: ┤9          ├┤5       ├─────┤5          ├┤9             ├
#               │           ││        │     │           ││              │
#    mul_res.6: ┤10         ├┤6       ├─────┤6          ├┤10            ├
#               │           ││  equal │     │  equal_dg ││              │
#    sbp_anc.0: ┤11         ├┤        ├─────┤           ├┤11            ├
#               │           ││        │     │           ││              │
#  sbp_anc_7.0: ┤12         ├┤        ├─────┤           ├┤12            ├
#               │           ││        │     │           ││              │
#  sbp_anc_8.0: ┤13         ├┤        ├─────┤           ├┤13            ├
#               │           ││        │     │           ││              │
#  sbp_anc_9.0: ┤14         ├┤        ├─────┤           ├┤14            ├
#               │           ││        │     │           ││              │
# sbp_anc_10.0: ┤15         ├┤        ├─────┤           ├┤15            ├
#               │           ││        │     │           ││              │
# sbp_anc_11.0: ┤16         ├┤        ├─────┤           ├┤16            ├
#               └───────────┘│        │┌───┐│           │└──────────────┘
#     eq_qbl.0: ─────────────┤7       ├┤ Z ├┤7          ├────────────────
#                            └────────┘└───┘└───────────┘
# Live QuantumVariables:
# ----------------------
# QuantumFloat qf

# %% [markdown]
# We can see how the multiplication is evaluated into a new QuantumFloat called `mul_res_0` using some ancilla qubits. Subsequently, a multi-controlled X-gate evaluates the condition of it to be equal to 0.25 into a qubit called `eq_cond_0`. The ancilla qubits and `eq_cond` will be recycled for each other during compilation, implying there is 0 qubit overhead for the ancillae:

# %%
qf.qs.compile().num_qubits()
# Out:
# 12

# %% [markdown]
# We perform the Z-gate and uncompute. The uncomputation is necessary here because the state the Grover diffuser acts on needs to be disentangled.
#
# > **Note**: QuantumVariables can be named independently of their name as a Python variable. If no name is provided, Qrisp tries to infer the name of the Python variable but in many cases there is ambiguity, meaning there is no guaranteed relation between the naming of the qubits and the name of the Python variable.
#
# ### Grover's algorithm
#
# The code for embedding the constructed oracle into Grover's algorithm is:

# %%
from math import pi
from qrisp.grover import diffuser

qf = QuantumFloat(3, -1, signed=True)

n = qf.size
iterations = int(0.25 * pi * (2**n / 2) ** 0.5)

h(qf)

for i in range(iterations):
    sqrt_oracle(qf)
    diffuser(qf)

print(qf)
# Out:
# {0.5: 0.4726316421014739, -0.5: 0.4726316421014739, 0.0: 0.003909765414075155, 1.0: 0.003909765414075155, 1.5: 0.003909765414075155, 2.0: 0.003909765414075155, 2.5: 0.003909765414075155, 3.0: 0.003909765414075155, 3.5: 0.003909765414075155, -4.0: 0.003909765414075155, -3.5: 0.003909765414075155, -3.0: 0.003909765414075155, -2.5: 0.003909765414075155, -2.0: 0.003909765414075155, -1.5: 0.003909765414075155, -1.0: 0.003909765414075155}

# %% [markdown]
# First we create the QuantumFloat which will contain the solution. Note that the QuantumFloat constructor creates unsigned floats by default. We determine the number of iterations according to the formula given [here](https://arxiv.org/abs/quant-ph/9909040), taking into consideration that we expect two solutions ($S = \{0.5, -0.5\}$). The next step is then to bring `qf` into uniform superposition, followed by the Grover iterations and finalized by a measurement (which is called by `print`). The [diffuser](../../reference/Primitives/Grover%20tools.rst) function applies the diffusion operator required for Grover's algorithm.
#
# ## Quantum Phase Estimation
#
# [Quantum phase estimation](https://en.wikipedia.org/wiki/Quantum_phase_estimation_algorithm) is an important subroutine in many quantum algorithms. We shortly summarize the problem this algorithm solves:
#
# Given is a unitary $U$ and quantum state $|\psi\rangle $ which is an eigenvector of $U$:
#
# $$U |\psi\rangle  = \text{exp}(i 2 \pi \phi)|\psi\rangle $$
#
# Applying quantum phase estimation to $U$ and $|\psi\rangle $ returns a quantum variable containing an estimate for the value of $\phi$.
#
# $$\text{QPE}_{U} |\psi\rangle  |0\rangle  = |\psi\rangle  |\phi\rangle  $$
#
# It can be implemented within a few lines of code in Qrisp:

# %%
from qrisp import QuantumFloat, control, QFT, h


def QPE(psi, U, precision):

    res = QuantumFloat(precision, -precision)

    h(res)

    for i in range(precision):
        with control(res[i]):
            for j in range(2**i):
                U(psi)

    return QFT(res, inv=True)

# %% [markdown]
# The first step here is to create the QuantumFloat `res` which will contain the result. The first argument specifies the amount of mantissa qubits, the QuantumFloat should contain and the second argument specifies the exponent. Having $n$ mantissa qubits and and exponent of $-n$ means that this QuantumFloat can represent the values between 0 and 1 with a granularity of $2^{-n}$.
#
# Subsequently we apply a Hadamard gate to all qubits of `res` and continue by performing controlled evaluations of $U$. This is achieved by using the `with control(res[i]):` statement. This statement enters a [ControlEnvironment](../../reference/Quantum%20Environments/ConditionEnvironment.rst) such that every quantum operation inside the indented code block will be controlled on the i-th qubit of `res`. We conclude the algorithm by performing an inverse [Quantum Fourier Transform](../../reference/Primitives/QFT.rst) of `res`.
#
# Note that compared to the [Qiskit implementation](https://qiskit.org/documentation/stubs/qiskit.circuit.library.PhaseEstimation.html) the Qrisp version comes with the convenience that $U$ can be given as a Python function (instead of a QuantumCircuit object) allowing for slim and elegant evaluations. Furthermore, the line `with control(res[i]):` invokes a ControlEnvironment, which can yield significant gains in performance if `qpe` is called within another ControlEnvironment (compared to the Qiskit approach of simply synthesizing the double controlled version for every participating gate).
#
# We test our code with a simple example:

# %%
from qrisp import p, QuantumVariable, multi_measurement
import numpy as np


def U(psi):
    phi_1 = 0.5
    phi_2 = 0.125

    p(phi_1 * 2 * np.pi, psi[0])
    p(phi_2 * 2 * np.pi, psi[1])


psi = QuantumVariable(2)

h(psi)

res = QPE(psi, U, 3)

# %% [markdown]
# In this code snippet, we define a function `U` which applies a phase gate onto the first two qubits of its input. We then create the QuantumVariable `psi` and bring it into uniform superposition by applying Hadamard gates onto each qubit. Subsequently, we evaluate `QPE` on `U` and `psi` with the precision 3.
#
# The quantum state is now:
#
# $$\frac{1}{2} \text{QPE}_{U}(|00\rangle  + |01\rangle + |10\rangle + |11\rangle)|0\rangle = \frac{1}{2} (|00\rangle|0\rangle + |10\rangle |\phi_1\rangle + |01\rangle|\phi_2\rangle +|11\rangle|(\phi_1 + \phi_2)\rangle)$$
#
# We verify by measuring `psi` together with `res` using the `multi_measurement` method:

# %%
print(multi_measurement([psi, res]))
# Out:
# {('00', 0.0): 0.25, ('10', 0.5): 0.25, ('01', 0.125): 0.25, ('11', 0.625): 0.25}
